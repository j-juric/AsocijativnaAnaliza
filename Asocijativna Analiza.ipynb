# %% [markdown]
# # Asocijativna analiza
# ## Tehnike i metode analize podataka
# ### Jovan Juric 1206
#
# Dataset preuzet sa linka: https://www.kaggle.com/akalyasubramanian/dataset-for-apriori-algorithm#__sid=js0

# %%
from csv import reader

#This method reads from the dataset
def read_csv(file_path):
    data = []
    item_set = set()
    with open (file_path, 'r') as file:
        csv_reader = reader(file)
        for items in csv_reader:
            data.append(items)
            tmp_item_set = set(items)
            for item in tmp_item_set:
                item_set.add(frozenset([item]))
    return data,item_set

# %%
data,item_set = read_csv('store_data.csv')

# %% [markdown]
# Ova metoda vrši izračunavanje *support* koeficijenta za dati skup artikala

# %%
def calc_support(data,item_set,item_supp_dict):
    supp=[]
    N = len(data)
    for item in item_set:
        counter = 0
        for item_list in data:
            if item.issubset(item_list):
                counter+=1
        supp_val = counter/N
        supp.append(supp_val)
        item_supp_dict[item]=supp_val
    return supp

# %% [markdown]
# Ova metoda vrši filtriranje skupova artikala na osnovu vrednosti *support* koeficijenta

# %%
def filter_above_min_support(item_set,support,min_val):
    new_item_set = set()            
    for i, item in enumerate(item_set):
        if support[i] > min_val:
            new_item_set.add(item)
    return new_item_set

# %% [markdown]
# Ova metoda služi za formiranje novih kandidata dodavanje jednog elementa postojećim skupovima.

# %%
def add_item_to_sets(item_set,k):
    new_item_set = [s1.union(s2) for s1 in item_set for s2 in item_set if len(s1.union(s2)) == k]
    return new_item_set

# %% [markdown]
# Metoda *prune* vrši izostavljanje skupova koji nisu frekventni.
#
# Metoda *powerset* za tadi skup vraća sve moguće podskupove tog skupa.

# %%
from itertools import combinations,chain

def prune(prev_item_set, curr_item_set, k):
    new_item_set = curr_item_set.copy()
    for item in new_item_set:
        possible_sets = combinations(item, k)
        for s in possible_sets:
            if frozenset(s) not in prev_item_set:
                new_item_set.remove(item)
                break
    return new_item_set

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(1,len(s)))

# %% [markdown]
# Metoda *conclusions* vrši izračunavanje asocijativnih pravila na osnovu izračunatih *support* vrednosti skupova. Vrši se izračunavanje pouzdanosti(*confidence*) nekih skupova u odnosu na druge pdoskupove i na osnovu toga se mogu izvršiti zaključci.

# %%
def conclusions(item_set_dict,item_supp_dict,min_val):
    deduction_list = []
    for key, item_set in item_set_dict.items():
        for item in item_set:
            possible_subsets = powerset(item)
            for subset in possible_subsets:
                confidence = item_supp_dict[item] / item_supp_dict[frozenset(subset)]
                if confidence > min_val:
                    deduction_list.append((confidence,set(subset),set(item.difference(subset))))
    return deduction_list

# %%
item_set_dict = dict()
item_supp_dict = dict()
support = calc_support(data,item_set,item_supp_dict)
item_set = filter_above_min_support(item_set,support,0.01)
k=2
while(len(item_set)):
    item_set_dict[k-1]=item_set
    new_item_set = add_item_to_sets(item_set,k)
    new_item_set = prune(item_set,new_item_set,k-1)
    support = calc_support(data,new_item_set,item_supp_dict)
    item_set = filter_above_min_support(new_item_set,support,0.01)
    k+=1

# %% [markdown]
# U nastavku možemo videti rezutate *apriori* algoritma. Ljudi često kupuju mineralnu vodu i iz tog razloga se možda može isključiti iz proračuna.

# %%
deduction_list = conclusions(item_set_dict,item_supp_dict,0.1)
deduction_list.sort(key = lambda x: x[0],reverse=True)
deduction_list
# Out:
# [(0.5066666666666667, {'eggs', 'ground beef'}, {'mineral water'}),
#  (0.503030303030303, {'ground beef', 'milk'}, {'mineral water'}),
#  (0.47398843930635837, {'chocolate', 'ground beef'}, {'mineral water'}),
#  (0.46892655367231634, {'frozen vegetables', 'milk'}, {'mineral water'}),
#  (0.45646437994722955, {'soup'}, {'mineral water'}),
#  (0.455026455026455, {'pancakes', 'spaghetti'}, {'mineral water'}),
#  (0.4476744186046512, {'olive oil', 'spaghetti'}, {'mineral water'}),
#  (0.44360902255639095, {'milk', 'spaghetti'}, {'mineral water'}),
#  (0.43568464730290457, {'chocolate', 'milk'}, {'mineral water'}),
#  (0.4353741496598639, {'ground beef', 'spaghetti'}, {'mineral water'}),
#  (0.43062200956937796, {'frozen vegetables', 'spaghetti'}, {'mineral water'}),
#  (0.42424242424242425, {'eggs', 'milk'}, {'mineral water'}),
#  (0.4190283400809717, {'olive oil'}, {'mineral water'}),
#  (0.41693811074918563, {'ground beef', 'mineral water'}, {'spaghetti'}),
#  (0.41655359565807326, {'ground beef'}, {'mineral water'}),
#  (0.40562248995983935, {'chocolate', 'eggs'}, {'mineral water'}),
#  (0.40476190476190477, {'chocolate', 'spaghetti'}, {'mineral water'}),
#  (0.4012539184952978, {'salmon'}, {'mineral water'}),
#  (0.3989637305699482, {'cereals'}, {'mineral water'}),
#  (0.3989145183175034, {'ground beef'}, {'spaghetti'}),
#  (0.3942558746736292, {'cooking oil'}, {'mineral water'}),
#  (0.3905109489051095, {'eggs', 'spaghetti'}, {'mineral water'}),
#  (0.38862559241706157, {'red wine'}, {'mineral water'}),
#  (0.38000000000000006, {'chicken'}, {'mineral water'}),
#  (0.37482517482517486, {'frozen vegetables'}, {'mineral water'}),
#  (0.3719806763285024, {'mineral water', 'olive oil'}, {'spaghetti'}),
#  (0.3703703703703704, {'milk'}, {'mineral water'}),
#  (0.36714975845410625, {'french fries', 'spaghetti'}, {'mineral water'}),
#  (0.36492890995260663, {'red wine'}, {'spaghetti'}),
#  (0.3567251461988304, {'tomatoes'}, {'mineral water'}),
#  (0.3548387096774194, {'pancakes'}, {'mineral water'}),
#  (0.3481781376518219, {'olive oil'}, {'spaghetti'}),
#  (0.348, {'avocado'}, {'mineral water'}),
#  (0.34501347708894875, {'herb & pepper'}, {'mineral water'}),
#  (0.3439635535307517, {'whole wheat rice'}, {'mineral water'}),
#  (0.3430321592649311, {'spaghetti'}, {'mineral water'}),
#  (0.34024896265560167, {'chocolate', 'milk'}, {'spaghetti'}),
#  (0.33992094861660077, {'mineral water', 'pancakes'}, {'spaghetti'}),
#  (0.33881578947368424, {'cake'}, {'mineral water'}),
#  (0.33582089552238803, {'frozen vegetables', 'mineral water'}, {'spaghetti'}),
#  (0.3333333333333333, {'grated cheese'}, {'mineral water'}),
#  (0.33027522935779813, {'burgers'}, {'eggs'}),
#  (0.3302238805970149, {'shrimp'}, {'mineral water'}),
#  (0.32884097035040427, {'herb & pepper'}, {'spaghetti'}),
#  (0.3277777777777778, {'milk', 'mineral water'}, {'spaghetti'}),
#  (0.3234501347708895, {'herb & pepper'}, {'ground beef'}),
#  (0.3213995117982099, {'chocolate'}, {'mineral water'}),
#  (0.32, {'frozen smoothie'}, {'mineral water'}),
#  (0.31741573033707865, {'honey'}, {'mineral water'}),
#  (0.3172690763052209, {'chocolate', 'eggs'}, {'spaghetti'}),
#  (0.3166144200626959, {'salmon'}, {'spaghetti'}),
#  (0.3155216284987277, {'grated cheese'}, {'spaghetti'}),
#  (0.313588850174216, {'low fat yogurt'}, {'mineral water'}),
#  (0.31130063965884863, {'turkey'}, {'eggs'}),
#  (0.31070496083550914, {'cooking oil'}, {'spaghetti'}),
#  (0.3097014925373134, {'frozen vegetables', 'mineral water'}, {'milk'}),
#  (0.30959752321981426, {'fresh bread'}, {'mineral water'}),
#  (0.3082706766917293, {'milk', 'spaghetti'}, {'chocolate'}),
#  (0.3070362473347548, {'turkey'}, {'mineral water'}),
#  (0.3060428849902534, {'tomatoes'}, {'spaghetti'}),
#  (0.3012658227848101, {'chocolate', 'mineral water'}, {'spaghetti'}),
#  (0.3007915567282322, {'soup'}, {'milk'}),
#  (0.30039525691699603, {'french fries', 'mineral water'}, {'spaghetti'}),
#  (0.2966417910447761, {'shrimp'}, {'spaghetti'}),
#  (0.29230769230769227, {'frozen vegetables'}, {'spaghetti'}),
#  (0.2916666666666667, {'milk', 'mineral water'}, {'chocolate'}),
#  (0.28832116788321166, {'eggs', 'spaghetti'}, {'chocolate'}),
#  (0.2866666666666667, {'chicken'}, {'spaghetti'}),
#  (0.2857142857142857, {'mineral water', 'spaghetti'}, {'ground beef'}),
#  (0.28338278931750743, {'eggs'}, {'mineral water'}),
#  (0.2823218997361478, {'soup'}, {'spaghetti'}),
#  (0.2801047120418848, {'eggs', 'mineral water'}, {'spaghetti'}),
#  (0.2798165137614679, {'burgers'}, {'mineral water'}),
#  (0.2789115646258503, {'chocolate', 'spaghetti'}, {'milk'}),
#  (0.27366255144032925, {'milk'}, {'spaghetti'}),
#  (0.27222222222222225, {'milk', 'mineral water'}, {'eggs'}),
#  (0.2703583061889251, {'ground beef', 'mineral water'}, {'milk'}),
#  (0.26870748299319724, {'chocolate', 'spaghetti'}, {'eggs'}),
#  (0.267100977198697, {'ground beef', 'mineral water'}, {'chocolate'}),
#  (0.26631853785900783, {'cooking oil'}, {'chocolate'}),
#  (0.26582278481012656, {'chocolate', 'mineral water'}, {'milk'}),
#  (0.265625, {'mineral water', 'spaghetti'}, {'chocolate'}),
#  (0.2650771388499299, {'pancakes'}, {'spaghetti'}),
#  (0.2643979057591623, {'eggs', 'mineral water'}, {'chocolate'}),
#  (0.220917225950783, {'mineral water'}, {'chocolate'}),
#  (0.22039473684210528, {'cake'}, {'french fries'}),
#  (0.21951219512195125, {'low fat yogurt'}, {'eggs'}),
#  (0.2162849872773537, {'grated cheese'}, {'ground beef'}),
#  (0.21594349142280528, {'green tea'}, {'french fries'}),
#  (0.21512605042016805, {'escalope'}, {'mineral water'}),
#  (0.2145748987854251, {'olive oil'}, {'ground beef'}),
#  (0.21364653243847875, {'mineral water'}, {'eggs'}),
#  (0.21294851794071765, {'french fries'}, {'eggs'}),
#  (0.211781206171108, {'pancakes'}, {'french fries'}),
#  (0.209926769731489, {'chocolate'}, {'french fries'}),
#  (0.20980091883614088, {'spaghetti'}, {'eggs'}),
#  (0.20897615708274897, {'pancakes'}, {'chocolate'}),
#  (0.20865139949109412, {'grated cheese'}, {'chocolate'}),
#  (0.20759493670886073, {'chocolate', 'mineral water'}, {'ground beef'}),
#  (0.20672268907563024, {'escalope'}, {'french fries'}),
#  (0.20501138952164008, {'whole wheat rice'}, {'chocolate'}),
#  (0.20489296636085627, {'burgers'}, {'milk'}),
#  (0.2046783625730994, {'tomatoes'}, {'chocolate'}),
#  (0.2046783625730994, {'tomatoes'}, {'milk'}),
#  (0.20367534456355285, {'spaghetti'}, {'milk'}),
#  (0.20352781546811397, {'ground beef'}, {'eggs'}),
#  (0.2032640949554896, {'eggs'}, {'spaghetti'}),
#  (0.2027334851936219, {'whole wheat rice'}, {'milk'}),
#  (0.20260374288039054, {'chocolate'}, {'eggs'}),
#  (0.20252225519287834, {'eggs'}, {'french fries'}),
#  (0.20134228187919462, {'mineral water'}, {'milk'}),
#  (0.20124804992199688, {'french fries'}, {'chocolate'}),
#  (0.20089285714285715, {'mineral water', 'spaghetti'}, {'frozen vegetables'}),
#  (0.2008072653884965, {'green tea'}, {'spaghetti'}),
#  (0.20052770448548812, {'soup'}, {'chocolate'}),
#  (0.2003058103975535, {'burgers'}, {'green tea'}),
#  (0.19999999999999998, {'frozen vegetables'}, {'french fries'}),
#  (0.19895287958115182, {'eggs', 'mineral water'}, {'ground beef'}),
#  (0.1986062717770035, {'low fat yogurt'}, {'spaghetti'}),
#  (0.19847328244274812, {'grated cheese'}, {'french fries'}),
#  (0.1977777777777778, {'chicken'}, {'green tea'}),
#  (0.19776119402985073, {'shrimp'}, {'eggs'}),
#  (0.19734789391575666, {'french fries'}, {'mineral water'}),
#  (0.19609438567941412, {'chocolate'}, {'milk'}),
#  (0.19571865443425074, {'burgers'}, {'chocolate'}),
#  (0.19337979094076657, {'low fat yogurt'}, {'chocolate'}),
#  (0.1927346115035318, {'green tea'}, {'eggs'}),
#  (0.1919642857142857, {'mineral water', 'spaghetti'}, {'pancakes'}),
#  (0.18976545842217488, {'turkey'}, {'green tea'}),
#  (0.18678815489749429, {'whole wheat rice'}, {'eggs'}),
#  (0.1847181008902077, {'eggs'}, {'chocolate'}),
#  (0.18444444444444444, {'chicken'}, {'french fries'}),
#  (0.18312757201646093, {'milk'}, {'french fries'}),
#  (0.18218623481781376, {'olive oil'}, {'eggs'}),
#  (0.1820987654320988, {'milk'}, {'frozen vegetables'}),
#  (0.18123667377398722, {'turkey'}, {'chocolate'}),
#  (0.18123667377398722, {'turkey'}, {'milk'}),
#  (0.17995444191343962, {'whole wheat rice'}, {'french fries'}),
#  (0.1793372319688109, {'tomatoes'}, {'eggs'}),
#  (0.1793372319688109, {'tomatoes'}, {'green tea'}),
#  (0.17762237762237765, {'frozen vegetables'}, {'ground beef'}),
#  (0.17759838546922302, {'green tea'}, {'chocolate'}),
#  (0.1768421052631579, {'frozen smoothie'}, {'green tea'}),
#  (0.17647058823529413, {'escalope'}, {'spaghetti'}),
#  (0.17543859649122806, {'tomatoes'}, {'french fries'}),
#  (0.17482517482517482, {'frozen vegetables'}, {'shrimp'}),
#  (0.17473684210526316, {'frozen smoothie'}, {'eggs'}),
#  (0.1743421052631579, {'cake'}, {'green tea'}),
#  (0.17421602787456447, {'low fat yogurt'}, {'french fries'}),
#  (0.17391304347826086, {'pancakes'}, {'milk'}),
#  (0.17367706919945725, {'ground beef'}, {'mineral water', 'spaghetti'}),
#  (0.17251051893408134, {'pancakes'}, {'green tea'}),
#  (0.17247386759581884, {'low fat yogurt'}, {'milk'}),
#  (0.17232021709633652, {'ground beef'}, {'frozen vegetables'}),
#  (0.17206477732793524, {'olive oil'}, {'frozen vegetables'}),
#  (0.171875, {'mineral water', 'spaghetti'}, {'olive oil'}),
#  (0.17170022371364654, {'mineral water'}, {'ground beef'}),
#  (0.17153996101364521, {'tomatoes'}, {'ground beef'}),
#  (0.17136498516320472, {'eggs'}, {'milk'}),
#  (0.1705756929637527, {'turkey'}, {'burgers'}),
#  (0.1705756929637527, {'turkey'}, {'french fries'}),
#  (0.1697530864197531, {'milk'}, {'ground beef'}),
#  (0.16964285714285715, {'mineral water', 'spaghetti'}, {'french fries'}),
#  (0.1692307692307692, {'frozen vegetables'}, {'tomatoes'}),
#  (0.16776315789473684, {'cake'}, {'chocolate'}),
#  (0.1669266770670827, {'french fries'}, {'green tea'}),
#  (0.16583747927031509, {'cookies'}, {'french fries'}),
#  (0.16447368421052633, {'cake'}, {'milk'}),
#  (0.1639676113360324, {'olive oil'}, {'pancakes'}),
#  (0.16374269005847952, {'tomatoes'}, {'shrimp'}),
#  (0.1628222523744912, {'ground beef'}, {'herb & pepper'}),
#  (0.16146645865834636, {'french fries'}, {'spaghetti'}),
#  (0.16044776119402984, {'shrimp'}, {'ground beef'}),
#  (0.16044776119402984, {'shrimp'}, {'green tea'}),
#  (0.1602373887240356, {'eggs'}, {'burgers'}),
#  (0.16003062787136293, {'spaghetti'}, {'frozen vegetables'}),
#  (0.15849923430321594, {'spaghetti'}, {'french fries'}),
#  (0.15671641791044774, {'shrimp'}, {'tomatoes'}),
#  (0.15587044534412955, {'olive oil'}, {'mineral water', 'spaghetti'}),
#  (0.12091988130563798, {'eggs'}, {'pancakes'}),
#  (0.12091988130563798, {'eggs'}, {'frozen vegetables'}),
#  (0.12079510703363913, {'burgers'}, {'frozen vegetables'}),
#  (0.12079510703363913, {'burgers'}, {'pancakes'}),
#  (0.12061711079943899, {'pancakes'}, {'mineral water', 'spaghetti'}),
#  (0.12021439509954057, {'spaghetti'}, {'tomatoes'}),
#  (0.11940298507462688, {'ground beef'}, {'tomatoes'}),
#  (0.11888111888111888, {'frozen vegetables'}, {'olive oil'}),
#  (0.11778471138845555, {'french fries'}, {'pancakes'}),
#  (0.11728395061728396, {'milk'}, {'soup'}),
#  (0.11668928086838534, {'ground beef'}, {'shrimp'}),
#  (0.11608391608391608, {'frozen vegetables'}, {'milk', 'mineral water'}),
#  (0.11577181208053693, {'mineral water'}, {'olive oil'}),
#  (0.1153324287652646, {'ground beef'}, {'grated cheese'}),
#  (0.11521252796420582, {'mineral water'}, {'cake'}),
#  (0.11419753086419754, {'milk'}, {'chicken'}),
#  (0.11360448807854139, {'pancakes'}, {'olive oil'}),
#  (0.11261872455902307, {'ground beef'}, {'milk', 'mineral water'}),
#  (0.11200807265388497, {'green tea'}, {'ground beef'}),
#  (0.11154446177847115, {'french fries'}, {'frozen vegetables'}),
#  (0.11127596439169138, {'eggs'}, {'ground beef'}),
#  (0.1112618724559023, {'ground beef'}, {'chocolate', 'mineral water'}),
#  (0.11079943899018233, {'pancakes'}, {'burgers'}),
#  (0.11079943899018233, {'pancakes'}, {'shrimp'}),
#  (0.11048951048951049, {'frozen vegetables'}, {'burgers'}),
#  (0.11008230452674898, {'milk'}, {'frozen smoothie'}),
#  (0.1098454027664768, {'chocolate'}, {'shrimp'}),
#  (0.10898082744702321, {'green tea'}, {'frozen vegetables'}),
#  (0.10830860534124628, {'eggs'}, {'turkey'}),
#  (0.1080246913580247, {'milk'}, {'tomatoes'}),
#  (0.1080246913580247, {'milk'}, {'chocolate', 'mineral water'}),
#  (0.1076923076923077, {'frozen vegetables'}, {'cake'}),
#  (0.10740439381611065, {'chocolate'}, {'escalope'}),
#  (0.10696266397578205, {'green tea'}, {'cake'}),
#  (0.1062937062937063, {'frozen vegetables'}, {'low fat yogurt'}),
#  (0.10608308605341245, {'eggs'}, {'cake'}),
#  (0.1045241809672387, {'french fries'}, {'cake'}),
#  (0.10414971521562244, {'chocolate'}, {'burgers'}),
#  (0.10413476263399693, {'spaghetti'}, {'cake'}),
#  (0.10312075983717775, {'ground beef'}, {'eggs', 'mineral water'}),
#  (0.10288065843621401, {'milk'}, {'cake'}),
#  (0.10234899328859061, {'mineral water'}, {'burgers'}),
#  (0.10234899328859061, {'mineral water'}, {'tomatoes'}),
#  (0.10185185185185186, {'milk'}, {'low fat yogurt'}),
#  (0.10082304526748971, {'milk'}, {'eggs', 'mineral water'}),
#  (0.10067114093959731, {'mineral water'}, {'low fat yogurt'}),
#  (0.1000813669650122, {'chocolate'}, {'olive oil'})]
